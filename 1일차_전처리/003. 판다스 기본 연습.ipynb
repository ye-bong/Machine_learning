# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/강의자료/머신러닝기초/1일차_머신러닝의 개요
# Out:
# /content/drive/MyDrive/강의자료/머신러닝기초/1일차_머신러닝의 개요

# %% [markdown]
# ## 0. 데이터 불러오기

# %% [markdown]
# ```python
# import pandas as pd
# import numpy as np
#
# data = pd.read_csv('./datasets/초등_4학년_수학_차시문항풀이이력.csv', index_col = 0)
# ```

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('./datasets/초등_4학년_수학_차시문항풀이이력.csv', index_col = 0)
data.head()
# Out:
#                                   사용자ID          차시코드       단원코드    단원제목  \
# 0  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 3  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 4  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
#
#               강의내용           강의명  학년  학기  시험구분 강의구분  ...       대단원코드   대단원제목  \
# 0  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 1  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 2  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 3  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 4  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
#
#         중단원코드    중단원제목       소단원코드         소단원제목        토픽코드  \
# 0  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234054.0
# 1  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12233718.0
# 2  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234058.0
# 3  14201237.0  다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233721.0
# 4  14201237.0  다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233719.0
#
#                                   토픽제목  난이도  평가영역
# 0                           모형 돈 세어 보기  2.0  91.0
# 1                           10000 알아보기  2.0  91.0
# 2  10000이 ■, 1000이 ▲ ……인 다섯 자리 수를 나타내기  2.0  91.0
# 3                      각 자릿수의 합으로 나타내기  3.0  91.0
# 4                각 자리의 숫자와 나타내는 값 알아보기  3.0  91.0
#
# [5 rows x 30 columns]

# %%
data.columns
# Out:
# Index(['사용자ID', '차시코드', '단원코드', '단원제목', '강의내용', '강의명', '학년', '학기', '시험구분',
#        '강의구분', '강의타입', '동영상재생시간', '실제재생시간', '확인문제점수', '학습일', '문항번호', '문항코드',
#        '사용자입력', '정오답', '영역', '대단원코드', '대단원제목', '중단원코드', '중단원제목', '소단원코드',
#        '소단원제목', '토픽코드', '토픽제목', '난이도', '평가영역'],
#       dtype='object')

# %% [markdown]
# ```python
# print('data 변수 type:',type(data))
# ```

# %% [markdown]
# ```python
# data.head()
# ```

# %%
data.head()
# Out:
#                                   사용자ID          차시코드       단원코드    단원제목  \
# 0  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 3  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 4  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
#
#               강의내용           강의명  학년  학기  시험구분 강의구분  ...       대단원코드   대단원제목  \
# 0  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 1  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 2  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 3  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 4  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
#
#         중단원코드    중단원제목       소단원코드         소단원제목        토픽코드  \
# 0  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234054.0
# 1  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12233718.0
# 2  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234058.0
# 3  14201237.0  다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233721.0
# 4  14201237.0  다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233719.0
#
#                                   토픽제목  난이도  평가영역
# 0                           모형 돈 세어 보기  2.0  91.0
# 1                           10000 알아보기  2.0  91.0
# 2  10000이 ■, 1000이 ▲ ……인 다섯 자리 수를 나타내기  2.0  91.0
# 3                      각 자릿수의 합으로 나타내기  3.0  91.0
# 4                각 자리의 숫자와 나타내는 값 알아보기  3.0  91.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ```python
# data.tail()
# ```

# %%
data.tail(1)
# Out:
#                                       사용자ID          차시코드       단원코드   단원제목  \
# 99999  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB  2. 각도
#
#               강의내용       강의명  학년  학기  시험구분 강의구분  ...       대단원코드  대단원제목  \
# 99999  각을 어떻게 그릴까요  수학 2단원-③   4   1   NaN    E  ...  17120996.0  2. 각도
#
#             중단원코드        중단원제목       소단원코드     소단원제목        토픽코드  \
# 99999  14201244.0  각도기로 각을 그리기  12233529.0  각 그리는 순서  12233790.0
#
#                   토픽제목  난이도  평가영역
# 99999  각도를 그리는 순서 알아보기  3.0  91.0
#
# [1 rows x 30 columns]

# %% [markdown]
# ```python
# display(data.head())
# display(data.tail())
# ```

# %%
display(data.head())
display(data.tail())
# Out:
#                                   사용자ID          차시코드       단원코드    단원제목  \
# 0  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 3  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 4  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
#
#               강의내용           강의명  학년  학기  시험구분 강의구분  ...       대단원코드   대단원제목  \
# 0  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 1  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 2  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 3  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
# 4  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  ...  17120995.0  1. 큰 수
#
#         중단원코드    중단원제목       소단원코드         소단원제목        토픽코드  \
# 0  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234054.0
# 1  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12233718.0
# 2  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234058.0
# 3  14201237.0  다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233721.0
# 4  14201237.0  다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233719.0
#
#                                   토픽제목  난이도  평가영역
# 0                           모형 돈 세어 보기  2.0  91.0
# 1                           10000 알아보기  2.0  91.0
# 2  10000이 ■, 1000이 ▲ ……인 다섯 자리 수를 나타내기  2.0  91.0
# 3                      각 자릿수의 합으로 나타내기  3.0  91.0
# 4                각 자리의 숫자와 나타내는 값 알아보기  3.0  91.0
#
# [5 rows x 30 columns]
#                                       사용자ID          차시코드       단원코드   단원제목  \
# 99995  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB003  T0ME41UAB  2. 각도
# 99996  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB  2. 각도
# 99997  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB  2. 각도
# 99998  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB  2. 각도
# 99999  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB  2. 각도
#
#                강의내용       강의명  학년  학기  시험구분 강의구분  ...       대단원코드  대단원제목  \
# 99995  각의 크기는 얼마일까요  수학 2단원-②   4   1   NaN    E  ...  17120996.0  2. 각도
# 99996   각을 어떻게 그릴까요  수학 2단원-③   4   1   NaN    E  ...  17120996.0  2. 각도
# 99997   각을 어떻게 그릴까요  수학 2단원-③   4   1   NaN    E  ...  17120996.0  2. 각도
# 99998   각을 어떻게 그릴까요  수학 2단원-③   4   1   NaN    E  ...  17120996.0  2. 각도
# 99999   각을 어떻게 그릴까요  수학 2단원-③   4   1   NaN    E  ...  17120996.0  2. 각도
#
#             중단원코드        중단원제목       소단원코드     소단원제목        토픽코드  \
# 99995  14201243.0     각의 크기 재기  12233528.0     각도 읽기  12233789.0
# 99996  14201244.0  각도기로 각을 그리기  12233597.0     각 그리기  12234072.0
# 99997  14201244.0  각도기로 각을 그리기  12233597.0     각 그리기  12234072.0
# 99998  14201244.0  각도기로 각을 그리기  12233597.0     각 그리기  12234072.0
# 99999  14201244.0  각도기로 각을 그리기  12233529.0  각 그리는 순서  12233790.0
#
#                              토픽제목  난이도  평가영역
# 99995             각도기를 사용하여 각을 재기  3.0  91.0
# 99996  기선 또는 꼭짓점과 각도를 주고 각을 그려 보기  2.0  91.0
# 99997  기선 또는 꼭짓점과 각도를 주고 각을 그려 보기  2.0  91.0
# 99998  기선 또는 꼭짓점과 각도를 주고 각을 그려 보기  3.0  91.0
# 99999             각도를 그리는 순서 알아보기  3.0  91.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ```python
# display(data.head(3))
# display(data.tail(3))
# ```

# %% [markdown]
# ```python
# #pd.set_option('display.max_rows', 1000)
# pd.set_option('display.max_columns', 30)
#
# data
# ```

# %%
pd.set_option('display.max_columns', 30)

# %%
data.head()
# Out:
#                                   사용자ID          차시코드       단원코드    단원제목  \
# 0  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 3  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 4  62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
#
#               강의내용           강의명  학년  학기  시험구분 강의구분 강의타입  동영상재생시간  실제재생시간  \
# 0  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 1  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 2  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 3  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 4  만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
#
#    확인문제점수                  학습일  문항번호        문항코드  \
# 0      -1  2022-07-04 21:00:03   1.0  30016642.0
# 1      -1  2022-07-04 21:00:03   2.0  30016654.0
# 2      -1  2022-07-04 21:00:03   3.0  30016589.0
# 3      -1  2022-07-04 21:00:03   4.0  30016571.0
# 4      -1  2022-07-04 21:00:03   5.0  30016608.0
#
#                                          사용자입력 정오답  영역       대단원코드   대단원제목  \
# 0                                        10000   O  MA  17120995.0  1. 큰 수
# 1              1000/^ROW^/100/^ROW^/10/^ROW^/1   O  MA  17120995.0  1. 큰 수
# 2                      713758/^ROW^/칠만십삼천칠배오십팔   X  MA  17120995.0  1. 큰 수
# 3  60000/^ROW^/3000/^ROW^/100/^ROW^/90/^ROW^/7   O  MA  17120995.0  1. 큰 수
# 4                                 천/^ROW^/2000   O  MA  17120995.0  1. 큰 수
#
#         중단원코드    중단원제목       소단원코드         소단원제목        토픽코드  \
# 0  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234054.0
# 1  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12233718.0
# 2  14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234058.0
# 3  14201237.0  다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233721.0
# 4  14201237.0  다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233719.0
#
#                                   토픽제목  난이도  평가영역
# 0                           모형 돈 세어 보기  2.0  91.0
# 1                           10000 알아보기  2.0  91.0
# 2  10000이 ■, 1000이 ▲ ……인 다섯 자리 수를 나타내기  2.0  91.0
# 3                      각 자릿수의 합으로 나타내기  3.0  91.0
# 4                각 자리의 숫자와 나타내는 값 알아보기  3.0  91.0

# %% [markdown]
# ```python
# data.shape
# ```

# %%
data.shape
# Out:
# (100000, 30)

# %% [markdown]
# ```python
# data.info()
# ```

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 30 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   사용자ID    100000 non-null  object
#  1   차시코드     100000 non-null  object
#  2   단원코드     100000 non-null  object
#  3   단원제목     100000 non-null  object
#  4   강의내용     100000 non-null  object
#  5   강의명      100000 non-null  object
#  6   학년       100000 non-null  int64
#  7   학기       100000 non-null  int64
#  8   시험구분     0 non-null       float64
#  9   강의구분     99357 non-null   object
#  10  강의타입     100000 non-null  object
#  11  동영상재생시간  100000 non-null  int64
#  12  실제재생시간   100000 non-null  int64
#  13  확인문제점수   100000 non-null  int64
#  14  학습일      100000 non-null  object
#  15  문항번호     92125 non-null   float64
#  16  문항코드     92125 non-null   float64
#  17  사용자입력    92125 non-null   object
#  18  정오답      92125 non-null   object
#  19  영역       92125 non-null   object
#  20  대단원코드    92125 non-null   float64
#  21  대단원제목    92125 non-null   object
#  22  중단원코드    91821 non-null   float64
#  23  중단원제목    91821 non-null   object
#  24  소단원코드    90446 non-null   float64
#  25  소단원제목    90446 non-null   object
#  26  토픽코드     90426 non-null   float64
#  27  토픽제목     90426 non-null   object
#  28  난이도      92125 non-null   float64
#  29  평가영역     91979 non-null   float64
# dtypes: float64(9), int64(5), object(16)
# memory usage: 23.7+ MB

# %% [markdown]
# ```python
# data.describe()
# ```

# %%
data.describe()
# Out:
#              학년        학기  시험구분        동영상재생시간         실제재생시간         확인문제점수  \
# count  100000.0  100000.0   0.0  100000.000000  100000.000000  100000.000000
# mean        4.0       1.0   NaN      48.730900     219.806440      10.741930
# std         0.0       0.0   NaN     103.727199    2630.562339      29.028563
# min         4.0       1.0   NaN      -1.000000      -1.000000      -1.000000
# 25%         4.0       1.0   NaN       0.000000      11.000000      -1.000000
# 50%         4.0       1.0   NaN       0.000000      31.000000      -1.000000
# 75%         4.0       1.0   NaN       0.000000     135.000000      -1.000000
# max         4.0       1.0   NaN     758.000000  176513.000000     100.000000
#
#                문항번호          문항코드         대단원코드         중단원코드         소단원코드  \
# count  92125.000000  9.212500e+04  9.212500e+04  9.182100e+04  9.044600e+04
# mean       3.524168  2.990135e+07  1.710045e+07  1.419278e+07  1.223326e+07
# std        2.621697  1.927374e+06  3.184194e+05  1.310045e+05  4.424683e+03
# min        1.000000  3.061000e+04  1.216006e+07  1.216019e+07  1.216060e+07
# 25%        2.000000  3.001662e+07  1.712100e+07  1.420124e+07  1.223353e+07
# 50%        3.000000  3.002045e+07  1.712100e+07  1.420125e+07  1.223355e+07
# 75%        4.000000  3.002487e+07  1.712100e+07  1.420126e+07  1.223356e+07
# max       20.000000  3.009349e+07  1.712126e+07  1.420130e+07  1.223366e+07
#
#                토픽코드           난이도          평가영역
# count  9.042600e+04  92125.000000  91979.000000
# mean   1.223361e+07      2.459028     91.251177
# std    4.371224e+03      0.529539      3.867551
# min    1.216185e+07      2.000000     54.000000
# 25%    1.223380e+07      2.000000     91.000000
# 50%    1.223386e+07      2.000000     91.000000
# 75%    1.223394e+07      3.000000     91.000000
# max    1.223434e+07      4.000000    180.000000

# %% [markdown]
# ```python
# data[['대단원제목', '중단원제목', '소단원제목', '토픽제목']]
# ```

# %%
data[['대단원제목', '중단원제목']]
# Out:
#         대단원제목        중단원제목
# 0      1. 큰 수      다섯 자리 수
# 1      1. 큰 수      다섯 자리 수
# 2      1. 큰 수      다섯 자리 수
# 3      1. 큰 수      다섯 자리 수
# 4      1. 큰 수      다섯 자리 수
# ...       ...          ...
# 99995   2. 각도     각의 크기 재기
# 99996   2. 각도  각도기로 각을 그리기
# 99997   2. 각도  각도기로 각을 그리기
# 99998   2. 각도  각도기로 각을 그리기
# 99999   2. 각도  각도기로 각을 그리기
#
# [100000 rows x 2 columns]

# %% [markdown]
# ```python
# data[['대단원제목', '중단원제목', '소단원제목', '토픽제목']].drop_duplicates()
# ```

# %%
data[['대단원제목', '중단원제목']].drop_duplicates()
# Out:
#              대단원제목                    중단원제목
# 0           1. 큰 수                  다섯 자리 수
# 35          1. 큰 수     10000이 몇십, 몇백, 몇천인 수
# 70          1. 큰 수                     억과 조
# 105          2. 각도                 각의 크기 재기
# 108          2. 각도              각도기로 각을 그리기
# 140          2. 각도      각도를 어림하고 합과 차를 알아보기
# 175          2. 각도          삼각형의 세 각의 크기의 합
# 178          2. 각도          사각형의 네 각의 크기의 합
# 210     3. 곱셈과 나눗셈                       곱셈
# 245     3. 곱셈과 나눗셈                      나눗셈
# 315    4. 평면도형의 이동                  평면도형 밀기
# 317    4. 평면도형의 이동                 평면도형 뒤집기
# 350    4. 평면도형의 이동                 평면도형 돌리기
# 354    4. 평면도형의 이동            평면도형을 뒤집고 돌리기
# 420       5. 막대그래프               막대그래프 알아보기
# 490       6. 규칙 찾기            수의 배열에서 규칙 찾기
# 525       6. 규칙 찾기               계산식의 규칙 찾기
# 526       6. 규칙 찾기                  규칙 알아보기
# 590            NaN                      NaN
# 638         1. 큰 수                    크기 비교
# 673          2. 각도               각의 크기 알아보기
# 763          2. 각도             각의 크기에 따른 분류
# 921     3. 각도와 삼각형             각의 크기에 따른 분류
# 1323   4. 평면도형의 이동                   무늬 꾸미기
# 1902        1. 큰 수                   뛰어서 세기
# 2427      6. 규칙 찾기           도형의 배열에서 규칙 찾기
# 2516   4. 평면도형의 이동                      NaN
# 6115        1. 큰 수                      NaN
# 6128         2. 각도                      NaN
# 6144    3. 곱셈과 나눗셈                      NaN
# 6175      5. 막대그래프                      NaN
# 6180      6. 규칙 찾기                      NaN
# 25927        1. 곱셈  1. (세 자리 수)×(한 자리 수)(1)
# 25937        1. 곱셈  2. (세 자리 수)×(한 자리 수)(2)
# 25947        1. 곱셈  3. (세 자리 수)×(한 자리 수)(3)
# 25957        1. 곱셈  4. (두 자리 수)×(두 자리 수)(1)
# 25977        1. 곱셈  5. (두 자리 수)×(두 자리 수)(2)
# 26007       2. 나눗셈  1. (두 자리 수)÷(한 자리 수)(1)
# 26047       2. 나눗셈  2. (두 자리 수)÷(한 자리 수)(2)
# 26067       2. 나눗셈     3. (세 자리 수)÷(한 자리 수)
# 26087       2. 나눗셈         4. 맞게 계산했는지 확인하기
# 26097         3. 원                     1. 원
# 26107         3. 원                 2. 원의 성질
# 26117         3. 원      3. 원으로 여러 가지 모양 그리기
# 26127        4. 분수               1. 분수 알아보기
# 26157        4. 분수              2. 진분수와 가분수
# 26167        4. 분수                   3. 대분수
# 26177        4. 분수             4. 분수의 크기 비교
# 26187    5. 들이와 무게               1. 들이 알아보기
# 26209    5. 들이와 무게              2. 들이의 합과 차
# 26219    5. 들이와 무게              3. 무게를 알아보기
# 26229    5. 들이와 무게              4. 무게의 합과 차
# 26249    6. 자료의 정리               1. 자료 정리하기
# 26259    6. 자료의 정리                 2. 그림그래프
# 26263    6. 자료의 정리             3. 그림그래프 그리기

# %% [markdown]
# ## 1. 데이터 확인하기(카운팅, 유니크 ..)

# %% [markdown]
# ```python
# value_counts = data['문항코드'].value_counts()
# print(value_counts)
# ```

# %%
data['대단원제목'].value_counts()
# Out:
# 2. 각도          21129
# 3. 곱셈과 나눗셈     16783
# 1. 큰 수         16077
# 4. 평면도형의 이동    13426
# 6. 규칙 찾기       13067
# 5. 막대그래프       11199
# 2. 나눗셈            90
# 1. 곱셈             80
# 3. 각도와 삼각형        74
# 3. 원              60
# 4. 분수             60
# 5. 들이와 무게         60
# 6. 자료의 정리         20
# Name: 대단원제목, dtype: int64

# %% [markdown]
# ```python
# value_counts = data['대단원제목'].value_counts()
# print(value_counts)
# ```

# %% [markdown]
# ```python
# value_counts = data['대단원제목'].value_counts(dropna=False)
# print(value_counts)
# ```

# %%
data['문항코드'].value_counts(dropna=False) # 널값 제거 X
# Out:
# NaN           7875
# 30016616.0     494
# 30016588.0     492
# 30016567.0     492
# 30016568.0     466
#               ...
# 30028514.0       1
# 30028513.0       1
# 30028512.0       1
# 30028511.0       1
# 30028023.0       1
# Name: 문항코드, Length: 968, dtype: int64

# %%
data['문항코드'].value_counts(dropna=True) # 널값 제거
# Out:
# 30016616.0    494
# 30016588.0    492
# 30016567.0    492
# 30016575.0    466
# 30016572.0    466
#              ...
# 30028514.0      1
# 30028513.0      1
# 30028512.0      1
# 30028511.0      1
# 30028023.0      1
# Name: 문항코드, Length: 967, dtype: int64

# %% [markdown]
# ```python
# data['정오답'].unique()
# ```

# %%
data['정오답']
# Out:
# 0        O
# 1        O
# 2        X
# 3        O
# 4        O
#         ..
# 99995    O
# 99996    O
# 99997    O
# 99998    O
# 99999    O
# Name: 정오답, Length: 100000, dtype: object

# %%
data['정오답'].unique()
# Out:
# array(['O', 'X', nan], dtype=object)

# %%
data['대단원제목'].unique()
# Out:
# array(['1. 큰 수', '2. 각도', '3. 곱셈과 나눗셈', '4. 평면도형의 이동', '5. 막대그래프',
#        '6. 규칙 찾기', nan, '3. 각도와 삼각형', '1. 곱셈', '2. 나눗셈', '3. 원', '4. 분수',
#        '5. 들이와 무게', '6. 자료의 정리'], dtype=object)

# %% [markdown]
# ```python
# data['정오답'] =  data['정오답'].map({'O': '정답', 'X': '오답'})
# ```

# %%
data['정오답'] = data['정오답'].map({'O' : '정답', 'X' : '오답'})

# %%
data['정오답']
# Out:
# 0        정답
# 1        정답
# 2        오답
# 3        정답
# 4        정답
#          ..
# 99995    정답
# 99996    정답
# 99997    정답
# 99998    정답
# 99999    정답
# Name: 정오답, Length: 100000, dtype: object

# %% [markdown]
# ## 2. 데이터 생성하기

# %% [markdown]
# ```python
# data['실제재생시간(분)'] = 0
# ```

# %%
data['실제재생시간']
# Out:
# 0         8
# 1         8
# 2         8
# 3         8
# 4         8
#          ..
# 99995    69
# 99996    67
# 99997    67
# 99998    67
# 99999    67
# Name: 실제재생시간, Length: 100000, dtype: int64

# %% [markdown]
# ```python
# data['실제재생시간(분)'] = data['실제재생시간']/60
# ```

# %%
data['실제재생시간(분)'] = data['실제재생시간']/60

# %%
data['실제재생시간(분)']
# Out:
# 0        0.133333
# 1        0.133333
# 2        0.133333
# 3        0.133333
# 4        0.133333
#            ...
# 99995    1.150000
# 99996    1.116667
# 99997    1.116667
# 99998    1.116667
# 99999    1.116667
# Name: 실제재생시간(분), Length: 100000, dtype: float64

# %% [markdown]
# ## 3. 데이터 집계하기

# %% [markdown]
# ```python
# contents_time = data['실제재생시간']
# print('contents_time max 값:', contents_time.max())
# print('contents_time sum 값:', contents_time.min())
# print('sum() contents_time:', sum(contents_time))
# print('contents_time + 3:\n',(contents_time + 3).head(3) )
# ```

# %%
contents_time = data['실제재생시간']
print('contents_time max 값:', contents_time.max())
print('contents_time sum 값:', contents_time.min())
print('sum() contents_time:', sum(contents_time))
print('contents_time + 3:\n',(contents_time + 3).head(3) )
# Out:
# contents_time max 값: 176513
# contents_time sum 값: -1
# sum() contents_time: 21980644
# contents_time + 3:
#  0    11
# 1    11
# 2    11
# Name: 실제재생시간, dtype: int64

# %%
contents_time.head(3)
# Out:
# 0    8
# 1    8
# 2    8
# Name: 실제재생시간, dtype: int64

# %% [markdown]
# ## 4. 데이터 인덱싱 및 필터링 하기

# %% [markdown]
# ```python
# data.iloc[0,0]
# ```

# %%
data.iloc[0,0]
# Out:
# '62fbd7b7-6a32-4da2-b203-acdec95e00b2'

# %% [markdown]
# ```python
# data.iloc[2,2]
# ```

# %% [markdown]
# ```python
# data.iloc[:,1]
# ```

# %%
data

# %%
data.iloc[:, 1]
# Out:
# 0        T0ME41U43001
# 1        T0ME41U43001
# 2        T0ME41U43001
# 3        T0ME41U43001
# 4        T0ME41U43001
#              ...
# 99995    T0ME41UAB003
# 99996    T0ME41UAB004
# 99997    T0ME41UAB004
# 99998    T0ME41UAB004
# 99999    T0ME41UAB004
# Name: 차시코드, Length: 100000, dtype: object

# %% [markdown]
# ```python
# data.iloc[:5,0]
# ```

# %% [markdown]
# ```python
# data.iloc[:5,0:3]
# ```

# %% [markdown]
# ```python
# data.iloc[:,:]
# ```

# %% [markdown]
# #### 조건에 맞는 데이터 찾기

# %% [markdown]
# ```python
# data[data['사용자ID'] == '62fbd7b7-6a32-4da2-b203-acdec95e00b2']
# ```

# %%
data[data['사용자ID'] == '62fbd7b7-6a32-4da2-b203-acdec95e00b2']

# %%
data[data['실제재생시간'] >10]
# Out:
#                                       사용자ID          차시코드       단원코드    단원제목  \
# 5      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 6      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 7      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 8      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 9      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# ...                                     ...           ...        ...     ...
# 99995  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB003  T0ME41UAB   2. 각도
# 99996  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99997  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99998  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99999  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
#
#                   강의내용           강의명  학년  학기  시험구분 강의구분 강의타입  동영상재생시간  실제재생시간  \
# 5      만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAB        0      43
# 6      만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAB        0      43
# 7      만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAB        0      43
# 8      만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAB        0      43
# 9      만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAB        0      43
# ...                ...           ...  ..  ..   ...  ...  ...      ...     ...
# 99995     각의 크기는 얼마일까요      수학 2단원-②   4   1   NaN    E    S        0      69
# 99996      각을 어떻게 그릴까요      수학 2단원-③   4   1   NaN    E  AAB      193      67
# 99997      각을 어떻게 그릴까요      수학 2단원-③   4   1   NaN    E  AAB      193      67
# 99998      각을 어떻게 그릴까요      수학 2단원-③   4   1   NaN    E  AAB      193      67
# 99999      각을 어떻게 그릴까요      수학 2단원-③   4   1   NaN    E  AAB      193      67
#
#        확인문제점수                  학습일  ...        문항코드  \
# 5          -1  2022-07-04 21:00:03  ...  30016642.0
# 6          -1  2022-07-04 21:00:03  ...  30016654.0
# 7          -1  2022-07-04 21:00:03  ...  30016589.0
# 8          -1  2022-07-04 21:00:03  ...  30016571.0
# 9          -1  2022-07-04 21:00:03  ...  30016608.0
# ...       ...                  ...  ...         ...
# 99995      -1  2022-03-22 18:01:50  ...  30020432.0
# 99996      -1  2022-03-23 17:31:12  ...  30020438.0
# 99997      -1  2022-03-23 17:31:12  ...  30020439.0
# 99998      -1  2022-03-23 17:31:12  ...  30020440.0
# 99999      -1  2022-03-23 17:31:12  ...  30020441.0
#
#                                              사용자입력 정오답  영역       대단원코드  \
# 5                                            10000  정답  MA  17120995.0
# 6                  1000/^ROW^/100/^ROW^/10/^ROW^/1  정답  MA  17120995.0
# 7                          713758/^ROW^/칠만십삼천칠배오십팔  오답  MA  17120995.0
# 8      60000/^ROW^/3000/^ROW^/100/^ROW^/90/^ROW^/7  정답  MA  17120995.0
# 9                                     천/^ROW^/2000  정답  MA  17120995.0
# ...                                            ...  ..  ..         ...
# 99995                                           지영  정답  MA  17120996.0
# 99996                                            ③  정답  MA  17120996.0
# 99997                                            ㉡  정답  MA  17120996.0
# 99998                                            ⑤  정답  MA  17120996.0
# 99999                            ㉢/^ROW^/㉡/^ROW^/㉠  정답  MA  17120996.0
#
#         대단원제목       중단원코드        중단원제목       소단원코드         소단원제목        토픽코드  \
# 5      1. 큰 수  14201237.0      다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234054.0
# 6      1. 큰 수  14201237.0      다섯 자리 수  12233514.0   다섯 자리 수의 이해  12233718.0
# 7      1. 큰 수  14201237.0      다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234058.0
# 8      1. 큰 수  14201237.0      다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233721.0
# 9      1. 큰 수  14201237.0      다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233719.0
# ...       ...         ...          ...         ...           ...         ...
# 99995   2. 각도  14201243.0     각의 크기 재기  12233528.0         각도 읽기  12233789.0
# 99996   2. 각도  14201244.0  각도기로 각을 그리기  12233597.0         각 그리기  12234072.0
# 99997   2. 각도  14201244.0  각도기로 각을 그리기  12233597.0         각 그리기  12234072.0
# 99998   2. 각도  14201244.0  각도기로 각을 그리기  12233597.0         각 그리기  12234072.0
# 99999   2. 각도  14201244.0  각도기로 각을 그리기  12233529.0      각 그리는 순서  12233790.0
#
#                                       토픽제목  난이도  평가영역  실제재생시간(분)
# 5                               모형 돈 세어 보기  2.0  91.0   0.716667
# 6                               10000 알아보기  2.0  91.0   0.716667
# 7      10000이 ■, 1000이 ▲ ……인 다섯 자리 수를 나타내기  2.0  91.0   0.716667
# 8                          각 자릿수의 합으로 나타내기  3.0  91.0   0.716667
# 9                    각 자리의 숫자와 나타내는 값 알아보기  3.0  91.0   0.716667
# ...                                    ...  ...   ...        ...
# 99995                      각도기를 사용하여 각을 재기  3.0  91.0   1.150000
# 99996           기선 또는 꼭짓점과 각도를 주고 각을 그려 보기  2.0  91.0   1.116667
# 99997           기선 또는 꼭짓점과 각도를 주고 각을 그려 보기  2.0  91.0   1.116667
# 99998           기선 또는 꼭짓점과 각도를 주고 각을 그려 보기  3.0  91.0   1.116667
# 99999                      각도를 그리는 순서 알아보기  3.0  91.0   1.116667
#
# [78216 rows x 31 columns]

# %% [markdown]
# ```python
# data[(data['사용자ID'] == '62fbd7b7-6a32-4da2-b203-acdec95e00b2') & (data['정오답'] == '정답')]
# ```

# %% [markdown]
# ## 5. 데이터 정렬, 그룹화 하기

# %% [markdown]
# ```python
# data = data.sort_values(by=['학습일'])
# ```

# %%
data.sort_values(by=['학습일'])
# Out:
#                                       사용자ID          차시코드       단원코드  \
# 8677   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8684   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8683   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8682   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# 8680   a5ba90e7-68fa-4d30-b553-ac59496e86af  T0ME41U01051  T0ME41U01
# ...                                     ...           ...        ...
# 22901  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05061  T0ME41U05
# 22902  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
# 22903  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
# 22904  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
# 22905  706baa2a-766e-413a-8248-acbef75c8c0c  T0ME41U05062  T0ME41U05
#
#            단원제목             강의내용             강의명  학년  학기  시험구분 강의구분 강의타입  \
# 8677     1. 큰 수  만, 다섯 자리 수 알아보기  수학 1단원 【준비학습①】   4   1   NaN    E  GAA
# 8684     1. 큰 수  만, 다섯 자리 수 알아보기  수학 1단원 【준비학습①】   4   1   NaN    E  GAJ
# 8683     1. 큰 수  만, 다섯 자리 수 알아보기  수학 1단원 【준비학습①】   4   1   NaN    E  GAJ
# 8682     1. 큰 수  만, 다섯 자리 수 알아보기  수학 1단원 【준비학습①】   4   1   NaN    E  GAI
# 8680     1. 큰 수  만, 다섯 자리 수 알아보기  수학 1단원 【준비학습①】   4   1   NaN    E  GAI
# ...         ...              ...             ...  ..  ..   ...  ...  ...
# 22901  5. 막대그래프            막대그래프          수학 5단원   4   1   NaN    E    M
# 22902  5. 막대그래프            막대그래프          수학 5단원   4   1   NaN    E    M
# 22903  5. 막대그래프            막대그래프          수학 5단원   4   1   NaN    E    M
# 22904  5. 막대그래프            막대그래프          수학 5단원   4   1   NaN    E    M
# 22905  5. 막대그래프            막대그래프          수학 5단원   4   1   NaN    E    M
#
#        동영상재생시간  실제재생시간  확인문제점수                  학습일  ...        문항코드  \
# 8677         0     257      -1  2021-12-13 23:11:20  ...  30016608.0
# 8684       244      31      -1  2021-12-13 23:11:20  ...  30016654.0
# 8683       244      31      -1  2021-12-13 23:11:20  ...  30016642.0
# 8682         0     101      -1  2021-12-13 23:11:20  ...  30016608.0
# 8680         0     101      -1  2021-12-13 23:11:20  ...  30016589.0
# ...        ...     ...     ...                  ...  ...         ...
# 22901      125      91      -1  2022-11-09 17:56:09  ...         NaN
# 22902      140     129      -1  2022-11-16 17:52:04  ...         NaN
# 22903      140     147      -1  2022-11-16 17:52:04  ...         NaN
# 22904      140     162      -1  2022-11-16 17:52:04  ...         NaN
# 22905      140     184      -1  2022-11-16 17:52:04  ...         NaN
#
#                                  사용자입력  정오답   영역       대단원코드   대단원제목  \
# 8677                      천/^ROW^/2000   정답   MA  17120995.0  1. 큰 수
# 8684   1000/^ROW^/100/^ROW^/10/^ROW^/1   정답   MA  17120995.0  1. 큰 수
# 8683                             10000   정답   MA  17120995.0  1. 큰 수
# 8682                      천/^ROW^/2000   정답   MA  17120995.0  1. 큰 수
# 8680             83758/^ROW^/팔만삼천칠백오십팔   정답   MA  17120995.0  1. 큰 수
# ...                                ...  ...  ...         ...     ...
# 22901                              NaN  NaN  NaN         NaN     NaN
# 22902                              NaN  NaN  NaN         NaN     NaN
# 22903                              NaN  NaN  NaN         NaN     NaN
# 22904                              NaN  NaN  NaN         NaN     NaN
# 22905                              NaN  NaN  NaN         NaN     NaN
#
#             중단원코드    중단원제목       소단원코드         소단원제목        토픽코드  \
# 8677   14201237.0  다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233719.0
# 8684   14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12233718.0
# 8683   14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234054.0
# 8682   14201237.0  다섯 자리 수  12233515.0  다섯 자리 수의 자릿값  12233719.0
# 8680   14201237.0  다섯 자리 수  12233514.0   다섯 자리 수의 이해  12234058.0
# ...           ...      ...         ...           ...         ...
# 22901         NaN      NaN         NaN           NaN         NaN
# 22902         NaN      NaN         NaN           NaN         NaN
# 22903         NaN      NaN         NaN           NaN         NaN
# 22904         NaN      NaN         NaN           NaN         NaN
# 22905         NaN      NaN         NaN           NaN         NaN
#
#                                       토픽제목  난이도  평가영역  실제재생시간(분)
# 8677                 각 자리의 숫자와 나타내는 값 알아보기  3.0  91.0   4.283333
# 8684                            10000 알아보기  2.0  91.0   0.516667
# 8683                            모형 돈 세어 보기  2.0  91.0   0.516667
# 8682                 각 자리의 숫자와 나타내는 값 알아보기  3.0  91.0   1.683333
# 8680   10000이 ■, 1000이 ▲ ……인 다섯 자리 수를 나타내기  2.0  91.0   1.683333
# ...                                    ...  ...   ...        ...
# 22901                                  NaN  NaN   NaN   1.516667
# 22902                                  NaN  NaN   NaN   2.150000
# 22903                                  NaN  NaN   NaN   2.450000
# 22904                                  NaN  NaN   NaN   2.700000
# 22905                                  NaN  NaN   NaN   3.066667
#
# [100000 rows x 31 columns]

# %%
data.sort_values(by=['학습일'])

# %% [markdown]
# ```python
# data = data.sort_values(by=['학습일'], ascending=False)
# ```

# %%
data.sort_values(by=['학습일'], ascending=False)

# %% [markdown]
# ```python
# data = data.sort_values(by=['대단원제목'])
# ```

# %% [markdown]
# ```python
# # DataFrame의 건수를 알고 싶다면 count() 보다는 shape를 이용
# data.count()
# ```

# %% [markdown]
# ```python
# data['확인문제점수'].mean()
# ```

# %% [markdown]
# ```python
# data_groupby_lunit = data.groupby(by='대단원제목')
# print(type(data_groupby_lunit))
# ```

# %%
data.groupby(by='대단원제목')

# %%
data.groupby(by='대단원제목').size()
# Out:
# 대단원제목
# 1. 곱셈             80
# 1. 큰 수         16077
# 2. 각도          21129
# 2. 나눗셈            90
# 3. 각도와 삼각형        74
# 3. 곱셈과 나눗셈     16783
# 3. 원              60
# 4. 분수             60
# 4. 평면도형의 이동    13426
# 5. 들이와 무게         60
# 5. 막대그래프       11199
# 6. 규칙 찾기       13067
# 6. 자료의 정리         20
# dtype: int64

# %% [markdown]
# ```python
# data_groupby_lunit.size()
# ```

# %% [markdown]
# ```python
# data_groupby_user = data.groupby(by='사용자ID')
# data_groupby_user.size()
# ```

# %%
data.groupby(by='대단원제목').size()
# Out:
# 대단원제목
# 1. 곱셈             80
# 1. 큰 수         16077
# 2. 각도          21129
# 2. 나눗셈            90
# 3. 각도와 삼각형        74
# 3. 곱셈과 나눗셈     16783
# 3. 원              60
# 4. 분수             60
# 4. 평면도형의 이동    13426
# 5. 들이와 무게         60
# 5. 막대그래프       11199
# 6. 규칙 찾기       13067
# 6. 자료의 정리         20
# dtype: int64

# %% [markdown]
# ```python
# data['정오답'] = data['정오답'].map({'정답': 1, '오답': 0})
# ```

# %%
data['정오답'] = data['정오답'].map({'정답' : 1, '오답' : 0})

# %% [markdown]
# ```python
# data.groupby('사용자ID')['정오답'].mean()
# ```

# %%
data.groupby('사용자ID')['정오답'].mean()

# %% [markdown]
# ```python
# data.isna()
# ```

# %% [markdown]
# ```python
# data['학년'].unique()
# ```

# %% [markdown]
# ## 6. 데이터 결측치 및 대체하기

# %% [markdown]
# ```python
# data.tail(3)
# ```

# %% [markdown]
# ```python
# data['난이도'] = data['난이도'].fillna(0)
# ```

# %%
data['난이도'].unique()
# Out:
# array([ 2.,  3.,  4., nan])

# %%
data['난이도'] = data['난이도'].fillna(0)

# %%
data['난이도'].unique()
# Out:
# array([2., 3., 4., 0.])

# %% [markdown]
# ```python
# data['정오답'] = data['정오답'].fillna(data['정오답'].mean())
# data.tail(3)
# ```

# %%
data['정오답'] = data['정오답'].fillna(data['정오답'].mean())

# %%
data['정오답'].unique()
# Out:
# array([1.        , 0.        , 0.70682225])

# %% [markdown]
# ```python
# data['학년'].replace(4, '4학년')
# ```

# %%
data['학년'].replace(4, '4학년')
# Out:
# 0        4학년
# 1        4학년
# 2        4학년
# 3        4학년
# 4        4학년
#         ...
# 99995    4학년
# 99996    4학년
# 99997    4학년
# 99998    4학년
# 99999    4학년
# Name: 학년, Length: 100000, dtype: object

# %%
data['학년']
# Out:
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 99995    4
# 99996    4
# 99997    4
# 99998    4
# 99999    4
# Name: 학년, Length: 100000, dtype: int64

# %% [markdown]
# ## 7. 데이터 가공하기

# %% [markdown]
# ```python
# def get_square(a):
#     return a**2
#
# print('3의 제곱은:',get_square(3))
# ```

# %%
def get_square(a):
    return a**2

print('3의 제곱은:',get_square(3))
# Out:
# 3의 제곱은: 9

# %% [markdown]
# ```python
# lambda_square = lambda x : x ** 2
# print('3의 제곱은:',lambda_square(3))
# ```

# %%
lambda_square = lambda x : x ** 2
print('3의 제곱은:',lambda_square(3))
# Out:
# 3의 제곱은: 9

# %% [markdown]
# ```python
# a=[1,2,3]
# squares = map(lambda x : x**2, a)
# list(squares)
# ```

# %%
a=[1,2,3]

# %%
list(map(lambda x : x**2, a))
# Out:
# [1, 4, 9]

# %% [markdown]
# ```python
# data['사용자ID길이']= data['사용자ID'].apply(lambda x : len(x))
# data[['사용자ID길이','사용자ID']].head(3)
# ```

# %%
len('hello')
# Out:
# 5

# %%
data['사용자ID길이'] = data['사용자ID'].apply(lambda x : len(x))

# %%
data[['사용자ID','사용자ID길이']]
# Out:
#                                       사용자ID  사용자ID길이
# 0      62fbd7b7-6a32-4da2-b203-acdec95e00b2       36
# 1      62fbd7b7-6a32-4da2-b203-acdec95e00b2       36
# 2      62fbd7b7-6a32-4da2-b203-acdec95e00b2       36
# 3      62fbd7b7-6a32-4da2-b203-acdec95e00b2       36
# 4      62fbd7b7-6a32-4da2-b203-acdec95e00b2       36
# ...                                     ...      ...
# 99995  7411afa9-4867-4f10-b353-adbc74743bf6       36
# 99996  7411afa9-4867-4f10-b353-adbc74743bf6       36
# 99997  7411afa9-4867-4f10-b353-adbc74743bf6       36
# 99998  7411afa9-4867-4f10-b353-adbc74743bf6       36
# 99999  7411afa9-4867-4f10-b353-adbc74743bf6       36
#
# [100000 rows x 2 columns]

# %% [markdown]
# ```python
# data['난이도수준'] = data['난이도'].apply(lambda x : '어려움' if x == 4.0 else '어렵지않음' )
# data[['난이도수준','난이도']].drop_duplicates()
# ```

# %%
data['난이도'].unique()
# Out:
# array([2., 3., 4., 0.])

# %%
data['난이도수준'] = data['난이도'].apply(lambda x : '어려움' if x == 4.0 else '어렵지않음' )
data[['난이도수준','난이도']].drop_duplicates()
# Out:
#      난이도수준  난이도
# 0    어렵지않음  2.0
# 3    어렵지않음  3.0
# 424    어려움  4.0
# 590  어렵지않음  0.0

# %% [markdown]
# ## 8. 데이터 인코딩, 스케일링

# %% [markdown]
# ```python
# from sklearn.preprocessing import LabelEncoder
# encoder = LabelEncoder()
# encoder.fit(data['차시코드'])
# labels = encoder.transform(data['차시코드'])
# labels
# ```

# %% [markdown]
# ```python
# data['차시코드'] = labels
# data
# ```

# %% [markdown]
# ```python
# data['난이도']
# ```

# %% [markdown]
# ```python
# pd.get_dummies(data, columns= ['난이도'])
# ```

# %%
pd.get_dummies(data, columns= ['난이도'])
# Out:
#                                       사용자ID          차시코드       단원코드    단원제목  \
# 0      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 1      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 2      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 3      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# 4      62fbd7b7-6a32-4da2-b203-acdec95e00b2  T0ME41U43001  T0ME41U43  1학기 복습
# ...                                     ...           ...        ...     ...
# 99995  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB003  T0ME41UAB   2. 각도
# 99996  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99997  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99998  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
# 99999  7411afa9-4867-4f10-b353-adbc74743bf6  T0ME41UAB004  T0ME41UAB   2. 각도
#
#                   강의내용           강의명  학년  학기  시험구분 강의구분 강의타입  동영상재생시간  실제재생시간  \
# 0      만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 1      만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 2      만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 3      만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# 4      만, 다섯 자리 수 알아보기  수학 1단원 【복습①】   4   1   NaN    E  AAA        0       8
# ...                ...           ...  ..  ..   ...  ...  ...      ...     ...
# 99995     각의 크기는 얼마일까요      수학 2단원-②   4   1   NaN    E    S        0      69
# 99996      각을 어떻게 그릴까요      수학 2단원-③   4   1   NaN    E  AAB      193      67
# 99997      각을 어떻게 그릴까요      수학 2단원-③   4   1   NaN    E  AAB      193      67
# 99998      각을 어떻게 그릴까요      수학 2단원-③   4   1   NaN    E  AAB      193      67
# 99999      각을 어떻게 그릴까요      수학 2단원-③   4   1   NaN    E  AAB      193      67
#
#        확인문제점수                  학습일  ...   대단원제목       중단원코드        중단원제목  \
# 0          -1  2022-07-04 21:00:03  ...  1. 큰 수  14201237.0      다섯 자리 수
# 1          -1  2022-07-04 21:00:03  ...  1. 큰 수  14201237.0      다섯 자리 수
# 2          -1  2022-07-04 21:00:03  ...  1. 큰 수  14201237.0      다섯 자리 수
# 3          -1  2022-07-04 21:00:03  ...  1. 큰 수  14201237.0      다섯 자리 수
# 4          -1  2022-07-04 21:00:03  ...  1. 큰 수  14201237.0      다섯 자리 수
# ...       ...                  ...  ...     ...         ...          ...
# 99995      -1  2022-03-22 18:01:50  ...   2. 각도  14201243.0     각의 크기 재기
# 99996      -1  2022-03-23 17:31:12  ...   2. 각도  14201244.0  각도기로 각을 그리기
# 99997      -1  2022-03-23 17:31:12  ...   2. 각도  14201244.0  각도기로 각을 그리기
# 99998      -1  2022-03-23 17:31:12  ...   2. 각도  14201244.0  각도기로 각을 그리기
# 99999      -1  2022-03-23 17:31:12  ...   2. 각도  14201244.0  각도기로 각을 그리기
#
#             소단원코드         소단원제목        토픽코드  \
# 0      12233514.0   다섯 자리 수의 이해  12234054.0
# 1      12233514.0   다섯 자리 수의 이해  12233718.0
# 2      12233514.0   다섯 자리 수의 이해  12234058.0
# 3      12233515.0  다섯 자리 수의 자릿값  12233721.0
# 4      12233515.0  다섯 자리 수의 자릿값  12233719.0
# ...           ...           ...         ...
# 99995  12233528.0         각도 읽기  12233789.0
# 99996  12233597.0         각 그리기  12234072.0
# 99997  12233597.0         각 그리기  12234072.0
# 99998  12233597.0         각 그리기  12234072.0
# 99999  12233529.0      각 그리는 순서  12233790.0
#
#                                       토픽제목  평가영역 실제재생시간(분)  사용자ID길이  난이도수준  \
# 0                               모형 돈 세어 보기  91.0  0.133333       36  어렵지않음
# 1                               10000 알아보기  91.0  0.133333       36  어렵지않음
# 2      10000이 ■, 1000이 ▲ ……인 다섯 자리 수를 나타내기  91.0  0.133333       36  어렵지않음
# 3                          각 자릿수의 합으로 나타내기  91.0  0.133333       36  어렵지않음
# 4                    각 자리의 숫자와 나타내는 값 알아보기  91.0  0.133333       36  어렵지않음
# ...                                    ...   ...       ...      ...    ...
# 99995                      각도기를 사용하여 각을 재기  91.0  1.150000       36  어렵지않음
# 99996           기선 또는 꼭짓점과 각도를 주고 각을 그려 보기  91.0  1.116667       36  어렵지않음
# 99997           기선 또는 꼭짓점과 각도를 주고 각을 그려 보기  91.0  1.116667       36  어렵지않음
# 99998           기선 또는 꼭짓점과 각도를 주고 각을 그려 보기  91.0  1.116667       36  어렵지않음
# 99999                      각도를 그리는 순서 알아보기  91.0  1.116667       36  어렵지않음
#
#        난이도_0.0 난이도_2.0  난이도_3.0  난이도_4.0
# 0            0       1        0        0
# 1            0       1        0        0
# 2            0       1        0        0
# 3            0       0        1        0
# 4            0       0        1        0
# ...        ...     ...      ...      ...
# 99995        0       0        1        0
# 99996        0       1        0        0
# 99997        0       1        0        0
# 99998        0       0        1        0
# 99999        0       0        1        0
#
# [100000 rows x 36 columns]

# %% [markdown]
# ```python
# from sklearn.preprocessing import StandardScaler, MinMaxScaler
#
# scaler = StandardScaler()
# scaler.fit(data[data['확인문제점수'] > 0]['확인문제점수'].to_frame())
# scaled_data = scaler.transform(data[data['확인문제점수'] > 0]['확인문제점수'].to_frame())
# scaled_data
# ```

# %% [markdown]
# ```python
# scaler = MinMaxScaler()
# scaler.fit(data['실제재생시간'].to_frame())
# scaled_data = scaler.transform(data['실제재생시간'].to_frame())
# scaled_data
# ```

# %% [markdown]
# ## 9. 간단 데이터 시각화

# %% [markdown]
# ```python
# data.head()
# ```

# %% [markdown]
# ```python
# import seaborn as sns
#
# sns.distplot(data['차시코드'])
# ```

# %%
import seaborn as sns
sns.histplot(data['차시코드'])
# Out:
# <Axes: xlabel='차시코드', ylabel='Count'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ```python
# #sns.distplot(data['난이도'])
# sns.histplot(data['난이도'])
# ```

# %%
sns.histplot(data['난이도'])
# Out:
# <Axes: xlabel='난이도', ylabel='Count'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 45212 (\N{HANGUL SYLLABLE NAN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45212 (\N{HANGUL SYLLABLE NAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 10. 데이터 학습, 테스트 셋 나누기

# %% [markdown]
# ```python
# X = data[['사용자ID', '강의명', '학습일', '문항코드', '대단원코드', '중단원코드', '소단원코드', '토픽코드']]
# Y = data['정오답']
# ```

# %%
X = data[['사용자ID', '강의명', '학습일', '문항코드', '대단원코드', '중단원코드', '소단원코드', '토픽코드']]
Y = data['정오답']

# %% [markdown]
# ```python
# from sklearn.model_selection import train_test_split
#
# X_train, X_test, y_train, y_test= train_test_split(X, Y, test_size=0.2, random_state=121)
# ```

# %%
# 학습-X, 테스트-X, 학습-y, 테스트-y

# %%
from sklearn.model_selection  import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X, Y, test_size=0.2, random_state=121)

# %%
X_train.shape
# Out:
# (80000, 8)

# %%
X_test.shape
# Out:
# (20000, 8)

# %% [markdown]
# ## 연습문제

# %% [markdown]
# 처음부터 시작하기

# %%
data = pd.read_csv('./datasets/초등_4학년_수학_차시문항풀이이력.csv', index_col = 0)
data.head()

# %% [markdown]
# 1. 학생별 평균점수 구하기

# %% [markdown]
# 2. 학생별 대단원별 평균점수 구하기

# %% [markdown]
# 3. 대단원별 평균점수 구하기

# %% [markdown]
# 4. 평균점수가 높은 순서대로 학생 줄세우기

# %% [markdown]
# 5. 데이터 건수가 많은 학생 순서대로 줄세우기

# %% [markdown]
# 6. 대단원 '1. 곱셈' 을 풀이한 데이터만 가지고 Train / Test set을 8:2로 나누어 보기

# %% [markdown]
# 7. 자유롭게 더 연습해보기
