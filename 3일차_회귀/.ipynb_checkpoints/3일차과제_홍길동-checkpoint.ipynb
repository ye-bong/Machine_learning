# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/강의자료/머신러닝기초/3일차_회귀

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 데이터 불러오기 : 자전거 대여량 수요 예측

# %%
df = pd.read_csv('./datasets/bike_train.csv')
pd.set_option('display.max_columns', len(df.columns))
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# 주요 컬럼 설명
# - datetime: hourly date + timestamp
# - season: 1 = 봄, 2 = 여름, 3 = 가을, 4 = 겨울
# - holiday: 1 = 토, 일요일의 주말을 제외한 국경일 등의 휴일, 0 = 휴일이 아닌 날
# - workingday: 1 = 토, 일요일의 주말 및 휴일이 아닌 주중, 0 = 주말 및 휴일
# - weather: 1 = 맑음, 약간 구름 낀 흐림 2 = 안개, 안개 + 흐림 3 = 가벼운 눈, 가벼운 비 + 천둥 4 = 심한 눈/비, 천둥/번개
# - temp: 온도(섭씨)
# - atemp: 체감온도(섭씨)
# - humidity: 상대습도
# - windspeed: 풍속
# - casual: 사전에 등록되지 않는 사용자가 대여한 횟수
# - registered: 사전에 등록된 사용자가 대여한 횟수
# - count: 대여 횟수

# %% [markdown]
# 자전거 대여 횟수(Y) 예측을 위해 X를 만들어 모델에 적용해보세요!

# %% [markdown]
# ### 데이터 전처리

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
# 컬럼별 결측치 확인
null_cnt_df = pd.DataFrame(df.isnull().sum()).rename(columns = {0:'null_count'}).reset_index()
null_cnt_df['null_ratio'] = round(null_cnt_df['null_count']/len(df) * 100, 2)
null_cnt_df
# Out:
#          index  null_count  null_ratio
# 0     datetime           0         0.0
# 1       season           0         0.0
# 2      holiday           0         0.0
# 3   workingday           0         0.0
# 4      weather           0         0.0
# 5         temp           0         0.0
# 6        atemp           0         0.0
# 7     humidity           0         0.0
# 8    windspeed           0         0.0
# 9       casual           0         0.0
# 10  registered           0         0.0
# 11       count           0         0.0

# %% [markdown]
# ### 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# 그래프 타이틀 한글 출력
matplotlib.rcParams['font.family'] ='Malgun Gothic'

# 맥북 version 한글 출력
#from matplotlib import rc
#rc('font', family='AppleGothic')
#plt.rcParams['axes.unicode_minus'] = False

# 그래프 사이즈 지정
plt.rcParams['figure.figsize'] = [12, 8]

# %%
plt.figure(figsize = (10, 5))
plt.bar(df['season'], df['count'])
plt.ylim(700, 1000)
plt.xlabel('시즌별', labelpad=15)
plt.ylabel('자전거 대여수', labelpad=20)
plt.xticks([1, 2,3,4],['봄','여름','가을','겨울'])
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.bar(df['workingday'], df['count'])
plt.ylim(600, 1000)
plt.xlabel('주말/주중별', labelpad=15)
plt.ylabel('자전거 대여수', labelpad=20)
plt.xticks([0, 1],['주말','주중'])
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.bar(df['holiday'], df['count'])
plt.ylim(600, 1000)
plt.xlabel('주말/주중별', labelpad=15)
plt.ylabel('자전거 대여수', labelpad=20)
plt.xticks([0, 1],['주말+주중','공휴일'])
plt.show()

# %% [markdown]
# #### 변수선택

# %%
plt.figure(figsize = (7, 5))
sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')
plt.title('상관계수')
plt.show()
# Out:
# C:\Users\leah5\AppData\Local\Temp\ipykernel_19532\4007878549.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\ProgramData\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 변수 간 연관성 검토 -> atemp와 temp 간 상관관계가 깊어보이므로 과적합을 막기위해 atemp 변수 삭제
sns.set_style('whitegrid')
sns.scatterplot(data=df, x='atemp', y='temp')
# Out:
# <Axes: xlabel='atemp', ylabel='temp'>

# %%
sns.set_style('whitegrid')
sns.scatterplot(data=df, x='casual', y='count')
# Out:
# <Axes: xlabel='casual', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.scatterplot(data=df, x='registered', y='count')
# count(종속변수)와 registered(독립변수) 사이에 깊은 상관관계가 있음. registered 유무가 중요 변수로 보임.
# Out:
# <Axes: xlabel='registered', ylabel='count'>

# %% [markdown]
# #### target 변수와 input 변수 나누기

# %%
X = df.drop(['datetime', 'atemp','count'], axis = 1)
y = df['count']

# %% [markdown]
# #### 데이터셋 분리

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state= 0)

# %% [markdown]
# #### 스케일링

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# ### 모델 적용 / 평가

# %%
# from sklearn.metrics import mean_squared_error, mean_absolute_error

# # 사이킷런의 mean_square_error() 를 이용하여 RMSE 계산
# def rmse(y,pred):
#     return np.sqrt(mean_squared_error(y,pred))

# # MSE, RMSE, RMSLE 를 모두 계산
# def evaluate_regr(y,pred):
#     rmse_val = rmse(y,pred)
#     # MAE 는 scikit learn의 mean_absolute_error() 로 계산
#     mae_val = mean_absolute_error(y,pred)
#     print('RMSE: {0:.3F}, MAE: {1:.3F}'.format(rmse_val, mae_val))

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
def mse(y,pred):
    return mean_squared_error(y,pred)
# 사이킷런의 mean_square_error() 를 이용하여 RMSE 계산
def rmse(y,pred):
    return np.sqrt(mean_squared_error(y,pred))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# y = df['count']
# X = df.drop(['count'],axis=1,inplace=False)

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

lr_reg = LinearRegression()

# %%
# lr_reg.fit(X_train, y_train)
# pred = lr_reg.predict(X_test)
# evaluate_regr(y_test ,pred)

# %%
lr_reg.fit(X_train, y_train)
pred = lr_reg.predict(X_test)
# evaluate_regr(y_test ,pred)
print("mse",mse(y_test,pred))
print("rmse",rmse(y_test,pred))
# 스케일링 하기 전보다 오류가 더 적은 예측이 됨 (성능 상승)
# Out:
# mse 1.061989521696237e-26
# rmse 1.0305287583062576e-13

# %%
#pd.DataFrame(data=[y_test_pd, pred_pd])

# %% [markdown]
# #### 예측값 확인 및 비교

# %%
y_test_pd = pd.DataFrame(y_test)
y_test_pd.reset_index(drop=True, inplace=True)
y_test_pd
# Out:
#       count
# 0       244
# 1       239
# 2       229
# 3       467
# 4       335
# ...     ...
# 2173    340
# 2174      4
# 2175    627
# 2176    450
# 2177     75
#
# [2178 rows x 1 columns]

# %%
pred_pd = pd.DataFrame(pred)
pred_pd.rename(columns={0:'count_pred'}, inplace=True)
pred_pd
# Out:
#       count_pred
# 0          244.0
# 1          239.0
# 2          229.0
# 3          467.0
# 4          335.0
# ...          ...
# 2173       340.0
# 2174         4.0
# 2175       627.0
# 2176       450.0
# 2177        75.0
#
# [2178 rows x 1 columns]

# %%
pd.concat([pred_pd,y_test_pd],axis=1)
# Out:
#       count_pred  count
# 0          244.0    244
# 1          239.0    239
# 2          229.0    229
# 3          467.0    467
# 4          335.0    335
# ...          ...    ...
# 2173       340.0    340
# 2174         4.0      4
# 2175       627.0    627
# 2176       450.0    450
# 2177        75.0     75
#
# [2178 rows x 2 columns]
